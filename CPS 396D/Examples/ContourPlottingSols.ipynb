# %% [markdown]
# # What Do I Look Like?

# %% [markdown]
# In this lab, you should submit a notebook via BlackBoard to answer the following questions.
#
# Look at the following equation for this lab:
#
# \begin{equation*}
# F(x, y) = 2(x - 1) * 5(y + 1)^2
# \end{equation*}

# %% [markdown]
# ## 1. Contour Plot
#
# Plot a contour plot of this function over the range $x = [-10, 10]$ and $y = [-10, 10]$

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
x = y = np.linspace(-10., 10., 21.)
X, Y = np.meshgrid(x, y)
Z = 2. * (X - 1.) * 5. *  (Y + 1.0)**2.

c = ax.contour(X, Y, Z, 50, cmap=mpl.cm.RdBu)

ax.axis('tight')
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   import sys
# Text(0,0.5,'y')

# %% [markdown]
# ## 2. 3D Plot
#
# Plot a 3D plot of this function over the range $x = [-10, 10]$ and $y = [-10, 10]$

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig, axes = plt.subplots(subplot_kw={'projection': '3d'})
norm = mpl.colors.Normalize(-abs(Z).max(), abs(Z).max())

p = axes.plot_surface(X, Y, Z, rstride=1, cstride=1, linewidth=0, antialiased=False, norm=norm, cmap=mpl.cm.Blues)
cb = fig.colorbar(p, ax=axes, shrink=0.6)

axes.set_title('Surface Plot of Equation')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_zlabel('z')
# Out:
# Text(0.5,0,'z')

# %% [markdown]
# ## 3. Filled Contour Plot
#
# Plot a contour plot of this function over the range $x = [-10, 10]$ and $y = [-10, 10]$. Add axis labelx, a title and a color legend.

# %%
fig, ax = plt.subplots()
x = y = np.linspace(-10., 10., 21.)
X, Y = np.meshgrid(x, y)
Z = 2. * (X - 1.) * 5. *  (Y + 1.0)**2.

c = ax.contourf(X, Y, Z, 50)

ax.axis('tight')
ax.set_title('Contour')
ax.set_xlabel('x')
ax.set_ylabel('y')
cb = fig.colorbar(c, shrink=0.6)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %% [markdown]
# ## 4. Root Estimation
#
# Based on these plots, is there a root to this equation? If so, what is the root?

# %% [markdown]
# Yes, at (1., -1.)
