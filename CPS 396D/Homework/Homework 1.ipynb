# %% [markdown]
# # Homework 1

# %%
# %matplotlib inline

import numpy as np
import math
import matplotlib as mpl
import matplotlib.pyplot as plt

numElems = 100
xLocs = np.linspace(0., 2. * math.pi, numElems)
yLocs = 4 * np.sin(xLocs)**3 + 2. * np.sin(xLocs)**2 - 2 * np.sin(xLocs) - 1.

fig, ax = plt.subplots()
ax.plot(xLocs, yLocs)

x_major_ticker = mpl.ticker.MultipleLocator(0.5)
x_minor_ticker = mpl.ticker.MultipleLocator(0.1)
y_major_ticker = mpl.ticker.MultipleLocator(0.5)
y_minor_ticker = mpl.ticker.MultipleLocator(0.1)
ax.xaxis.set_major_locator(x_major_ticker)
ax.yaxis.set_major_locator(y_major_ticker)
ax.xaxis.set_minor_locator(x_minor_ticker)
ax.yaxis.set_minor_locator(y_minor_ticker)

ax.grid(color="black", which="major", axis='x', linestyle='-', linewidth=0.25)
ax.grid(color="black", which="major", axis='y', linestyle='-', linewidth=0.25)


roots = [xInt for idx, xInt in enumerate(xLocs) if (yLocs[idx] < 0.12 and yLocs[idx] > -0.12)]
print(roots[:2])
# Out:
# [0.7615982190520711, 2.3482611754105527]
